# %% [markdown]
# <!--start-block-->
# <hr style="height: 1px;">
# <i>This code was authored by the 8.S50x Course Team, Copyright 2021 MIT All Rights Reserved.</i>
# <hr style="height: 1px;">
# <br>
#
# # RECITATION 1: Poisson Statistics and Probability
#
# <br>
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
# <hr style="height: 1px;">
#
# ## 1.0 Overview of Learning Objectives
#
# In this recitation we will explore the following objectives:
#
# - Understand the definitions of Random Variables and Probability Density Functions
# - See examples of Gaussians with different mean and variance
# - Make plots of different Gaussians using numpy
# - Joint Probability Density Functions
# - The Poisson distribution
#
# There's also an optional section for the exponential distribution if you finish the above in time.
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
# <hr style="height: 1px;">
#
# ## 1.1.0 Random Variables
#
#
# We will begin today with the concept of random variable, which is essential to probability and statistics.
#
# <p style="color:blue; text-align:center"><i>A <b>random variable</b> is (for the purposes of this class) an observable whose outcome may differ between experiments.</i></p>
#
# For example, if you're measuring the length of a cube in your experiment, the length you measure is a random variable. This is because your measured results conceivably might vary, depending on how you take the measurement and the precision of the ruler, or even thermal expansion and contraction of the cube.
#
# If you're measuring the number of snakes in a population, the number of snakes you count is also a random variable.
#
# <i>Technical note:</i> A random variable represents any possible values that the measurement could produce. The actual measured results are not random variables; they are data points. We often represent random variables by capital letters and their measured values as lowercase letters.
#
# There are two types of random variables, continuous and discrete. Discrete random variables can only take on discrete values (snake example), whereas continuous random variables can take on continuous values (cube example).
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
#
# ## 1.1.1 Probability Density Functions
#
# Discrete random variables are associated with a probability mass function that defines the exact probability that the random variable will take a certain discrete value. More precisely,
#
# <p style="color:blue; text-align:center"><i>The <b>probability mass function (PMF)</b> for a discrete random variable $R$ is a function $p(r)$ that maps from possible values $r$ of $R$ to the probability that $R=r$.</i></p>
#
# <i>Corollary:</i> the sum of $p(r)$ over all possible values of $R$ is 1. Thus, $p(r)$ is unitless
#
# For continuous probability distributions, we have instead a probability density function.
#
# <p style="color:blue; text-align:center"><i>The <b>probability density funtion (PDF)</b> for a continuous random variable $R$ is a function $P(r)$ defined on possible values $r$ of $R$, such that the probability that $R$ is between $a$ and $b$ is given by</i></p>
#
# $$p(a < R < b) = \int_{a}^{b} P(r) dr.$$
#
# Here, we adopt the convention that lowercase $p$ represent probabilities, and uppercase $P$ denote probability densities.
#
# <i>Corollary:</i> the integral of $P(r)$ over all possible values of $r$ is 1. Thus, $P(r)$ has units of $1/r$.
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
#
# ## 1.3 Gaussian distribution
#
#
# The most common probability distribution is the Gaussian or normal distribution, which represents many natural phenomena, especially in physics. The normal distribution for a random variable $X$ with mean  $\mu$ and standard deviation $\sigma$ is given by
#
# $$P(x) = \frac{1}{\sqrt{2\pi \sigma^2}} \exp\left(-\frac{1}{2}\frac{(x-\mu)^2}{\sigma^2}\right)$$
#
# Let's use numpy to make some plots of the various Gaussian distributions.
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
# #### <span style="color:#BA2220">>>>EXERCISE</span>
#
# Write python code that computes the Gaussian PDF $P(x)$ for $\mu=0$ and $\sigma^2=0.2$.  This code should be a function named `p` which accepts a single argument `x`.  It should work properly when `x` is a 1D numpy array.
#
#
# <span style="opacity:0.5"><i>Click this cell to display initial code for the cell below, if needed again.</i></span>
#
# <!--
# #initial code
# import numpy as np
# def p(x):
#     return # your code here
# -->
#
# <!--
# #solution
# import numpy as np
# def p(x):
#     return 1/np.sqrt(2 * np.pi * 0.2) * np.exp(-0.5 * x**2 / 0.2)
# -->
#
# <!--end-block-->

# %%
import numpy as np

def p(x):
    return 1.0 / np.sqrt(2 * np.pi * 0.2) * np.exp(-0.5 * x**2, 0.2)

# %% [markdown]
# <!--start-block-->
# #### <span style="color:#BA2220">>>>EXERCISE</span>
#
# Define probability density functions (PDFs) for the following Gaussian distributions over random variable $x$ for $x \in (-5,5)$
#
# 1. $\mu=0, \sigma^2 = 0.2$
# 2. $\mu=0, \sigma^2 = 1.0$
# 3. $\mu=0, \sigma^2 = 5.0$
# 4. $\mu=-2, \sigma^2 = 0.5$
#
# The PDFs are designated in the following way: "gaussmu0sig02" $\Leftrightarrow$ $(\mu=0, \sigma^2 = 0.2)$
#
#
# <!--
# #initial code
# def gaussmu0sig02(x):
#     return # your code here
#
# def gaussmu0sig10(x):
#     return # your code here
#
# def gaussmu0sig50(x):
#     return # your code here
#
# def gaussmum2sig05(x):
#     return # your code here
# -->
#
#
# <!--
# #solution
# def gaussmu0sig02(x):
#     return 1/np.sqrt(2 * np.pi * 0.2) * np.exp(-0.5 * x**2 / 0.2)
#
# def gaussmu0sig10(x):
#     return 1/np.sqrt(2 * np.pi * 1.0) * np.exp(-0.5 * x**2 / 1.0)
#
# def gaussmu0sig50(x):
#     return 1/np.sqrt(2 * np.pi * 5.0) * np.exp(-0.5 * x**2 / 5.0)
#
# def gaussmum2sig05(x):
#     return 1/np.sqrt(2 * np.pi * 0.5) * np.exp(-0.5 * (x+2)**2 / 0.5)
# -->
#
# <!--end-block-->

# %%
def gaussmu0sig02(x):
    return 1/np.sqrt(2 * np.pi * 0.2) * np.exp(-0.5 * x**2 / 0.2)

def gaussmu0sig10(x):
    return 1/np.sqrt(2 * np.pi * 1.0) * np.exp(-0.5 * x**2 / 1.0)

def gaussmu0sig50(x):
    return 1/np.sqrt(2 * np.pi * 5.0) * np.exp(-0.5 * x**2 / 5.0)

def gaussmum2sig05(x):
    return 1/np.sqrt(2 * np.pi * 0.5) * np.exp(-0.5 * (x+2)**2 / 0.5)

# %% [markdown]
# <!--start-block-->
# #### <span style="color:green">>>>RUN</span>
#
# Plot the functions that you defined in the previous step.
#
#
# <!--
# #initial code
# import matplotlib.pyplot as plt
#
# x = np.linspace(-5,5, 1000) #make a vector of points from -5 to 5 with 1000 data points
#
# plt.plot(x, gaussmu0sig02(x), label = "$\mu=0, \sigma^2 = 0.2$")
# plt.plot(x, gaussmu0sig10(x), label = "$\mu=0, \sigma^2 = 1.0$")
# plt.plot(x, gaussmu0sig50(x), label = "$\mu=0, \sigma^2 = 5.0$")
# plt.plot(x, gaussmum2sig05(x), label = "$\mu=-2, \sigma^2 = 5.0$")
# plt.legend()
# -->
#
# <!--end-block-->

# %%
import matplotlib.pyplot as plt

x = np.linspace(-5,5, 1000) #make a vector of points from -5 to 5 with 1000 data points
    
plt.plot(x, gaussmu0sig02(x), label = "$\mu=0, \sigma^2 = 0.2$")
plt.plot(x, gaussmu0sig10(x), label = "$\mu=0, \sigma^2 = 1.0$")
plt.plot(x, gaussmu0sig50(x), label = "$\mu=0, \sigma^2 = 5.0$")
plt.plot(x, gaussmum2sig05(x), label = "$\mu=-2, \sigma^2 = 0.5$")
plt.legend();

# %% [markdown]
# <!--start-block-->
# #### <span style="color:purple">>>>QUESTION</span>
#
#
# For a fixed value of $\mu$, what effect will increasing the standard deviation $\sigma$ have on the distribution?
#
# <!--
# #solution
# Increasing sigma widens the distribution.
# -->
#
# <br>
# <!--end-block-->

# %% [markdown]
# <br>
# <!--start-block-->
# <hr style="height: 1px;">
#
# ## 1.4 Joint Probability Density Functions
#
# We can define joint probability density functions, e.g. $P(x,y)$, for multivariate probability distributions in a similar way.
#
# <p style="color:blue; text-align:center"><i>The <b>joint PDF</b> for two continuous random variables $X$ and $Y$ is a function $P(x, y)$ defined on possible values $x$ of $X$ and $y$ of $Y$, such that the probability that $X$ and $Y$ are in some region $R$ is given by</i></p>
#
# $$p((X, Y)\in R) = \iint_{R} P(x, y) dx dy$$
#
# We define the single variable PDFs $P(x)$ and $P(y)$ by integrating (or marginalizing) the extra variable from the joint PDF, i.e.
#
# $P(x) = \int_{-\infty}^{\infty} P(x,y) dy$ and $P(y) = \int_{-\infty}^{\infty} P(x,y) dx$
#
# (Here, we implicitly assumed that the possible values of $X$ and $Y$ are the whole real number line.)
#
# Now we can introduce another very useful term in statistics:
#
# <p style="color:blue; text-align:center"><i>Two random varibales $X$ and $Y$ are <b>independent</b> from one another if the joint PDF factors into the product of the two single-variable PDFs:</i>
#
# $$P(x, y) = P(x) P(y).$$
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
#
# Given $k$ independent Gaussian random variables, the above definition of independence guarantees that the joint PDF is
#
#
# $$P(x_1, x_2, ... x_k) = \prod_{i=1}^k P(x_i) = \frac{1}{ (2\pi)^{k/2}\prod_i \sigma_i} \exp \left(-\frac{1}{2}\sum_i \frac{(x_i- \mu_i)^2}{\sigma_i^2}\right)$$
#
# Now let's visualize a multivariate Gaussian of two random variables.
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
# #### <span style="color:#BA2220">>>>EXERCISE</span>
#
# Write python code that computes the probability density functions (PDFs) for a multivariate Gaussian distribution over independent random variables $X$ and $Y$, for $\mu_x=\mu_y=0$ and $\sigma^2_x=\sigma^2_y=1$.
#
#
# <!--
# #initial code
# import numpy as np
# def P(x,y):
#     return # your code here
# -->
#
# <!--
# #solution
# import numpy as np
# def P(x,y):
#     return 1/(2 * np.pi) * np.exp(-0.5 * (x**2 + y**2))
# -->
# <!--end-block-->

# %%
import numpy as np
def p(x,y):
    return 1/(2 * np.pi) * np.exp(-0.5 * (x**2 + y**2))# your code here

# %% [markdown]
# <!--start-block-->
# #### <span style="color:green">>>>RUN</span>
#
# Using matplotlib and numpy, plot the PDF that you defined above over the region $x \in (-5,5), y\in(-5,5)$
#
# <!--
# #initial code
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
#
# fig1 = plt.figure()
#
# ax = fig1.add_subplot(111, projection = '3d')
#
# x = np.linspace(-5, 5, 1000)
# y = np.linspace(-5, 5, 1000)
#
# x,y = np.meshgrid(x,y)
#
# ax.plot_surface(x,y,p(x,y))
# fig2 = plt.figure(figsize = (5,5))
# plt.pcolormesh(x,y,p(x,y))
# plt.show();
# -->
# <!--end-block-->

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

fig1 = plt.figure()

ax = fig1.add_subplot(111, projection = '3d')

x = np.linspace(-5, 5, 1000)
y = np.linspace(-5, 5, 1000)

x,y = np.meshgrid(x,y)

ax.plot_surface(x,y,p(x,y))

fig2 = plt.figure(figsize = (5,5))
plt.pcolormesh(x,y,p(x,y))
plt.show();
# Out:
# <ipython-input-18-e34f354b8d6c>:17: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(x,y,p(x,y))

# %% [markdown]
# <!--start-block-->
# #### <span style="color:purple">>>>QUESTION</span>
#
# How would changing the mean and variance of one distribution affect the overall distribution?
#
# <!--
# #solution
# Changing the mean moves the center of the distribution, and changing the standard deviation stretches it into an ellipse. The ellipse's axes are always aligned with the $x$ and $y$ axes; you cannot rotate the ellipse with independent variables.
# -->
#
# <br>
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
# <hr style="height: 1px;">
#
# ## 1.5 Poisson Distributions
#
# Another very common distribution in physics is the Poisson distribution:
#
# <p style="color:blue; text-align:center"><i>For a sequence of events that are independent of each other and independent of time, a random variable representing the number of events occuring within a given interval obeys the <b>Poisson distribution</b>.</i></p>
#
# Examples include
# - the number of radioactive decays within a material over one second
# - the number of photons detected from a distant star in one day
# - the number of meteorite impacts on Earth in one year
#
# Note that Poisson-distributed random variables are discrete.
#
# The PMF of a Poisson-distributed random variable with unitless parameter $\lambda$ is
#
# $$p(k)=\frac{\lambda^k e^{-\lambda}}{k!}.$$
#
# You can view $\lambda$ as the average rate of events times the time interval over which $k$ events are detected.
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
# #### <span style="color:green">>>>RUN</span>
#
# Let's see what a Poisson distribution looks like. Run the cell below.
#
# <!--
# #initial code
# import numpy as np
# import matplotlib.pyplot as plt
#
# l = [1,5,10,25] # lambda value of the Poisson distribution
# hists = {} # Dictionary that will contain the Poisson-distributed data, listed by l value
#
# fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(20,5))
# for k in range(len(ax)):
#     s = np.random.poisson(l[k],1500)
#     hists[l[k]]=s
#     bins = np.arange(0, np.max(s) + 1, 1) - 0.5
#     ax[k].hist(s, bins=bins, density=True, label="Poisson data")
#     x = np.linspace(min(s),max(s),100)
#     ax[k].plot(x,(1/(np.sqrt(2*np.pi*l[k])))*np.exp(-0.5*(x-l[k])**2.0/l[k]), label="Gaussian dist.")
#     ax[k].axvline(x=l[k],c='r', label="Gaussian mean")
#     ax[k].legend(loc="upper right")
#     ax[k].set_title(f"lambda={l[k]}", y=-0.15)
# -->
#
# <!--end-block-->

# %%
import numpy as np
import matplotlib.pyplot as plt

l = [1,5,10,25] # lambda value of the Poisson distribution
hists = {} # Dictionary that will contain the Poisson-distributed data, listed by l value

fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(20,5))
for k in range(len(ax)):
    s = np.random.poisson(l[k],1500)
    hists[l[k]]=s
    bins = np.arange(0, np.max(s) + 1, 1) - 0.5
    ax[k].hist(s, bins=bins, density=True, label="Poisson data")
    x = np.linspace(min(s),max(s),100)
    ax[k].plot(x,(1/(np.sqrt(2*np.pi*l[k])))*np.exp(-0.5*(x-l[k])**2.0/l[k]), label="Gaussian dist.")
    ax[k].axvline(x=l[k],c='r', label="Gaussian mean")
    ax[k].legend(loc="upper right")
    ax[k].set_title(f"lambda={l[k]}", y=-0.15)

# %% [markdown]
# <!--start-block-->
# #### <span style="color:#BA2220">>>>EXERCISE</span>
#
# Using the numpy functions for mean and variance, compute the mean and variance of the data corresponding to $\lambda=25.$ This data is given to you as `h` below. Print the result.
#
# <!--
# #initial code
# import numpy as np
#
# h = hists[25]
#
# h_mean = #your code here
# h_var = #your code here
#
# print("Mean:",h_mean)
# print("Variance:",h_var)
# -->
#
# <!--
# #solution
# import numpy as np
#
# h = hists[25]
#
# h_mean = np.mean(h)
# h_var = np.var(h)
#
# print("Mean:",h_mean)
# print("Variance:",h_var)
# -->
# <!--end-block-->

# %%
import numpy as np

h = hists[25]

h_mean = np.mean(h)#your code here
h_var = np.var(h)#your code here

print("Mean:",h_mean)
print("Variance:",h_var)
# Out:
# Mean: 0.982
# Variance: 0.9723426666666666

# %% [markdown]
# <!--start-block-->
# #### <span style="color:purple">>>>QUESTION</span>
#
# Try this for values of $\lambda=1,5,10$. What is the connection between $\lambda$, the data mean, and the data variance?
#
# <!--
# #solution
# The mean, varaince, and lambda are always the same. This is a very important fact of Poisson distributions. Since Poisson distributions look Gaussian for high lambda, you often see Poisson distributions approximated as Gaussians with standard deviation equal to the square root of their means. You'll see this approximation again when we talk about $\chi^2$ tests.
# -->
#
# <br>
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
# <hr style="height: 1px;">
#
# ## 1.6 Simulating a Poisson Process
#
#
# Let's simulate a **Poisson process**, which is just a process leading to a set of events that
# - Are independent of time, meaning that they are not more or less frequent depending on the time of detection
# - Are independent of each other, meaning the probability distribution of one event is unaffected by the presence of other events
#
# Then a random variable that counts these events occuring within an interval is Poisson-distributed.
#
# <!--A Poisson process is defined via a sequence of exponential random variables $\tau_i$, with parameter $\lambda$. The process is defined in terms of $T_n=\sum_{i=1}^n \tau_i$ (the *n-th arrival time*), and $N(s)=\max(n:T_n\leq s)$ (the *number of arrivals*).-->
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
#
# Let's make a list of random event times. Convince yourself that these events are truly independent, since their distribution (the uniformly random distribution) is the only distribution that depends neither on time nor the presence of other events.
#
# #### <span style="color:green">>>>RUN</span>
#
# <!--
# #initial code
# import numpy as np
# import matplotlib.pyplot as plt
#
# NUM_EVENTS = 500
# TIME_RANGE = 250
#
# print("Average event rate:", NUM_EVENTS / TIME_RANGE, "events per second")
#
# event_times = # your code here
# event_times.sort()
#
# plt.plot(event_times)
# plt.xlabel("Event number")
# plt.ylabel("Time of occurence");
# -->
#
# <!--
# #solution
# import numpy as np
# import matplotlib.pyplot as plt
#
# NUM_EVENTS = 500
# TIME_RANGE = 250
#
# print("Average event rate:", NUM_EVENTS / TIME_RANGE, "events per second")
#
# event_times = np.random.random(NUM_EVENTS) * TIME_RANGE
# event_times.sort()
#
# plt.plot(event_times)
# plt.xlabel("Event number")
# plt.ylabel("Time of occurence");
# -->
#
# <!--end-block-->

# %%
import numpy as np
import matplotlib.pyplot as plt

NUM_EVENTS = 500
TIME_RANGE = 250

print("Average event rate:", NUM_EVENTS / TIME_RANGE, "events per second")

event_times = np.random.random(NUM_EVENTS) * TIME_RANGE# your code here
event_times.sort()

plt.plot(event_times)
plt.xlabel("Event number")
plt.ylabel("Time of occurence");
# Out:
# Text(0, 0.5, 'Time of event')

# %% [markdown]
# <!--start-block-->
#
# Let's count the number of events occuring in every interval of 1 second and display it in a histogram.
#
# #### <span style="color:green">>>>RUN</span>
#
# <!--
# #initial code
# import numpy as np
# import matplotlib.pyplot as plt
#
# TIME_INTERVAL = 1
#
# num_intervals = TIME_RANGE // TIME_INTERVAL
#
# counts = [np.sum(
#         (event_times > i * TIME_INTERVAL) & (event_times < (i+1) * TIME_INTERVAL)
#     ) for i in range(num_intervals)]
#
# bins = np.arange(np.max(counts))-0.5 # Center the bins on the integers
# plt.hist(counts, bins=bins, density=True)
# plt.xlabel("Number of events in a 1s interval")
# plt.ylabel("Fraction of intervals in data set");
# -->
#
# <!--end-block-->

# %%
import numpy as np
import matplotlib.pyplot as plt

TIME_INTERVAL = 1

num_intervals = TIME_RANGE // TIME_INTERVAL

counts = [np.sum(
        (event_times > i * TIME_INTERVAL) & (event_times < (i+1) * TIME_INTERVAL)
    ) for i in range(num_intervals)]

bins = np.arange(np.max(counts)+1)-0.5 # Center the bins on the integers
plt.hist(counts, bins=bins, density=True)
plt.xlabel("Number of events in a 1s interval")
plt.ylabel("Fraction of intervals in data set");

# %% [markdown]
# <!--start-block-->
# #### <span style="color:#BA2220">>>>EXERCISE</span>
#
# Using the above code and the Poisson distribution PMF, overplot the Poisson PMF with appropriate $\lambda$. Feel free to ask for hints.
#
# <!--
# #initial code
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.special import factorial
#
# plt.hist(counts, bins=bins, density=True)
# plt.xlabel("Number of events in interval")
# plt.ylabel("Fraction of intervals")
#
# l = #your lambda here
#
# #your plotting code here
# -->
#
# <!--
# #solution
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.special import factorial
#
# plt.hist(counts, bins=bins, density=True)
# plt.xlabel("Number of events in interval")
# plt.ylabel("Fraction of intervals")
#
# l = TIME_INTERVAL * (NUM_EVENTS / TIME_RANGE)
#
# k = np.arange(np.max(counts), dtype=int)
# plt.plot(k, l**k * np.exp(-l) / factorial(k));
# -->
#
# <!--end-block-->

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import factorial

plt.hist(counts, bins=bins, density=True)
plt.xlabel("Number of events in interval")
plt.ylabel("Fraction of intervals")

l = NUM_EVENTS / TIME_RANGE * TIME_INTERVAL#your lambda here

#your plotting code here
ks = np.arange(0, np.max(counts))
ys = l**ks * np.exp(-l) / factorial(ks)
plt.plot(ks, ys)

# %% [markdown]
# <!--start-block-->
# Don't believe that the Poisson distribution fits the data? Try playing with the parameters (`NUM_EVENTS`, `TIME_RANGE`, and `TIME_INTERVAL`). Explore different interval lengths. Try large numbers of events per interval if you want a very good fit between the Poisson PMF and the data.
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
#
# <hr style="height: 1px;">
#
# ## Optional excersize: Exponential distributions
#
# For Poisson processes, we've seen that
# * The probability distribution of each event's time of occurence is <b>uniform</b>
# * The probability distribution of the number of events occuring within an interval is <b>Poisson</b>
#
# However, we have not discussed the probability distribution of the time between events. It turns out to be exponential, with PDF
#
# $$P(\Delta t)= r e^{-r \Delta t}$$
#
# where $r$ is the average event rate.
#
# <!--end-block-->

# %% [markdown]
# <!--start-block-->
#
# Let's demonstrate this from our above data.
#
# #### <span style="color:green">>>>RUN</span>
#
# <!--
# #initial code
# import numpy as np
# import matplotlib.pyplot as plt
#
# bins = np.linspace(0, 1, 10)
# deltas = [event_times[i+1] - event_times[i] for i in range(NUM_EVENTS - 1)]
#
# exp_lambda = TIME_INTERVAL * (NUM_EVENTS / TIME_RANGE)
# plt.hist(deltas, density=True, label="Observed distribution", bins=bins)
# plt.plot(bins, np.exp(-exp_lambda * bins) * exp_lambda);
# -->
# <!--end-block-->

# %%
import numpy as np
import matplotlib.pyplot as plt

bins = np.linspace(0, 1, 10)
deltas = [event_times[i+1] - event_times[i] for i in range(NUM_EVENTS - 1)]

rate = (NUM_EVENTS / TIME_RANGE)
plt.hist(deltas, density=True, label="Observed distribution", bins=bins)
plt.plot(bins, np.exp(-rate * bins) * rate)
plt.xlabel("Time between events")
plt.ylabel("Fraction of events");

# %% [markdown]
# <!--start-block-->
# #### <span style="color:purple">>>>QUESTION</span>
#
# Why is the probability distribution of the time between independent events exponential?
#
# <span style="opacity:0.5">Hint: Suppose you detect an event and start waiting for the next one. Some time has passed and you're still waiting. Has the probability distribution changed shape due to the fact that you waited or is it still the same?</span>
#
# <span style="opacity:0.5">Hint 2: The probability distribution has not changed after you've waited some time $T$ (why?). That means that whatever the PDF $P(\Delta t)$ is, we must have $P(\Delta t) \propto P(\Delta t + T)$. The constant of proportionality is independent of $\Delta t$, and this formula is true for all $T$. Find a general class of distributions that satisfy this property. Then find the only distribution which has the $1/r$ as the expected value for $\Delta t$.</span>
#
# <!--
# #solution
# Suppose you detect an event and immediately start a stopwatch. Then some time $T$ passes with no events detected. The events are assumed to be independent of time, so given that time $T$ has passed, the probability distribution for how much time will pass until the next event has not changed. That means that $P(\Delta t) \propto P(\Delta t + T)$, with a factor of proportionality set by how likely it was for you to be able to wait for time $T$ wthout detecting an event in the first place.
#
# The only distributions that satisfy this property are $P(\Delta t) = Ae^{-\lambda_0 \Delta t}$, where $A$ is a normalization constant and $\lambda_0$ is some positive real number. Requiring that $\int_0^\infty P(\Delta t) d\Delta t = 1$, we have $A=\lambda_0$.
#
# We need the expectation value of $P(\Delta t)$ to be the average time between events, which is $1/\lambda$. Since $\int_0^\infty d\Delta t \Delta t \lambda_0 e^{-\lambda_0 \Delta t} = 1/\lambda_0$, we must have $\lambda_0 = \lambda$. Thus, the probability distribution for the time between events $\Delta t$ is
# $$P(\Delta t) = \lambda e^{-\lambda \Delta t}.$$
# -->
#
# <br>
# <!--end-block-->
